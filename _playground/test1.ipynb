# %%
from pathlib import Path

from ngio import open_ome_zarr_container

from fractal_uzh_converters.cq3k.convert_cq3k_compute_task import (
    convert_cq3k_compute_task,
)
from fractal_uzh_converters.cq3k.convert_cq3k_init_task import (
    AcquisitionInputModel,
    convert_cq3k_init_task,
)

from ome_zarr_converters_tools import (
    AdvancedComputeOptions
)

# %%
# zarr_dir = Path("/Volumes/scuanalysis-2/Hierlemann/carolina/Yokogawa_CQ3000/test_ome_zarr_output")
# test_data = Path("/Volumes/scuanalysis-2/Hierlemann/carolina/Yokogawa_CQ3000/20250729T171334_20X_dry_ST2036Q10W")

zarr_dir = Path("/links/shared/scuanalysis/ome-zarr-tests/P2013_Hierlemann_00013587")
test_data = Path("/links/shared/scuanalysis/Hierlemann/carolina/Yokogawa_CQ3000/P2013_Hierlemann_00013586/20251212T014449_20X_W")
test_data = Path("/links/shared/scuanalysis/Hierlemann/carolina/Yokogawa_CQ3000/P2013_Hierlemann_00013587/20251211T214540_20X_W")

p_list = convert_cq3k_init_task(
    zarr_dir=str(zarr_dir),
    acquisitions=[
        AcquisitionInputModel(
            path=str(test_data),
            acquisition_id=0,
        ),
    ],
    overwrite=True,
    advanced_options=AdvancedComputeOptions(invert_y=True)
)

# %%
p_list['parallelization_list'] = [p_list['parallelization_list'][54]]

# %%
print(p_list["parallelization_list"][0])
print(len(p_list["parallelization_list"]))
# assert len(p_list["parallelization_list"]) == 1
from tqdm import tqdm

for p in tqdm(p_list["parallelization_list"]):
    results = convert_cq3k_compute_task(**p)
    assert "image_list_updates" in results
    updates = results["image_list_updates"]
    assert len(updates) == 1
# Out:
# {'zarr_url': '/links/shared/scuanalysis/ome-zarr-tests/P2013_Hierlemann_00013587/20251211T214540_20X_W_Maximum.zarr/B/2/0', 'init_args': {'tiled_image_pickled_path': '/links/shared/scuanalysis/ome-zarr-tests/P2013_Hierlemann_00013587/_tmp_converter_dir/e8fb713e-8ee8-4c3b-b949-3a59a87c50b7.pkl', 'overwrite': True, 'advanced_compute_options': {'num_levels': 5, 'tiling_mode': 'auto', 'swap_xy': False, 'invert_x': False, 'invert_y': True, 'max_xy_chunk': 4096, 'z_chunk': 10, 'c_chunk': 1, 't_chunk': 1}}}
# 1
# 100%|██████████| 1/1 [00:30<00:00, 30.64s/it]

# %%
https://hms-dbmi.github.io/vizarr/?source=https://bs-dw114:8000/P2013_Hierlemann_00013587/20251211T214540_20X_W_Maximum.zarr/B/2/0
